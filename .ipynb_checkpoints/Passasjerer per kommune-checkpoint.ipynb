# %%
import pandas as panda 
import numpy as np
from scipy.stats import norm
from datetime import datetime
from matplotlib import pyplot as plt

# %%
main_df = panda.read_csv('Ruter_data.csv',delimiter=';')

# %%
passasjerer_kommuner = main_df[['Kommune','Passasjerer_Ombord']]

# %%
passasjerer_kommuner
# Out:
#          Kommune  Passasjerer_Ombord
# 0          Bærum                   5
# 1          Bærum                   5
# 2          Bærum                   6
# 3          Bærum                  10
# 4          Bærum                  10
# ...          ...                 ...
# 5995  Lillestrøm                   2
# 5996  Lillestrøm                   2
# 5997      Sagene                   3
# 5998  Gamle Oslo                   5
# 5999  Lillestrøm                  -5
#
# [6000 rows x 2 columns]

# %%
groupkommune = passasjerer_kommuner

# %%
groupkommune
# Out:
#          Kommune  Passasjerer_Ombord
# 0          Bærum                   5
# 1          Bærum                   5
# 2          Bærum                   6
# 3          Bærum                  10
# 4          Bærum                  10
# ...          ...                 ...
# 5995  Lillestrøm                   2
# 5996  Lillestrøm                   2
# 5997      Sagene                   3
# 5998  Gamle Oslo                   5
# 5999  Lillestrøm                  -5
#
# [6000 rows x 2 columns]

# %%
groupkommune.groupby('Kommune').sum()
# Out:
#                    Passasjerer_Ombord
# Kommune
# Alna                             2198
# Asker                            1730
# Aurskog-Høland                    570
# Bjerke                           1494
# Bærum                            1601
# Drammen                            42
# Eidsvoll                          583
# Enebakk                           338
# Frogner                           209
# Gamle Oslo                       1781
# Gjerdrum                          358
# Grorud                            491
# Grünerløkka                       651
# Hurdal                             24
# Indre Østfold                      19
# Lier                              178
# Lillestrøm                       5022
# Lørenskog                        2397
# Nannestad                         507
# Nes                               312
# Nittedal                          932
# Nordmarka                         -17
# Nordre Aker                        26
# Nordre Follo                       33
# Nordstrand                        302
# Rælingen                         1049
# Sagene                            222
# Sentrum                           423
# St.Hanshaugen                     156
# Stovner                           770
# Søndre Nordstrand                 113
# Ullensaker                       1577
# Ullern                            490
# Vestre Aker                       496

# %%
passPrKommune = main_df.groupby(['Kommune'])['Passasjerer_Ombord'].sum().sort_values(ascending=False)

# %%
passPrKommune
# Out:
# Kommune
# Lillestrøm           5022
# Lørenskog            2397
# Alna                 2198
# Gamle Oslo           1781
# Asker                1730
# Bærum                1601
# Ullensaker           1577
# Bjerke               1494
# Rælingen             1049
# Nittedal              932
# Stovner               770
# Grünerløkka           651
# Eidsvoll              583
# Aurskog-Høland        570
# Nannestad             507
# Vestre Aker           496
# Grorud                491
# Ullern                490
# Sentrum               423
# Gjerdrum              358
# Enebakk               338
# Nes                   312
# Nordstrand            302
# Sagene                222
# Frogner               209
# Lier                  178
# St.Hanshaugen         156
# Søndre Nordstrand     113
# Drammen                42
# Nordre Follo           33
# Nordre Aker            26
# Hurdal                 24
# Indre Østfold          19
# Nordmarka             -17
# Name: Passasjerer_Ombord, dtype: int64

# %%
plt.xlabel('Sum Passasjerer')
passPrKommune.plot(figsize=(20,20),kind='barh')
# Out:
# <AxesSubplot:xlabel='Sum Passasjerer', ylabel='Kommune'>
