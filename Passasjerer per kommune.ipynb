# %%
import pandas as panda 
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

# %%
main_df = panda.read_csv('Ruter_data.csv',delimiter=';')

# %%
passasjerer_kommuner = main_df[['Kommune','Passasjerer_Ombord']]

# %%
passasjerer_kommuner
# Out:
#          Kommune  Passasjerer_Ombord
# 0          Bærum                   5
# 1          Bærum                   5
# 2          Bærum                   6
# 3          Bærum                  10
# 4          Bærum                  10
# ...          ...                 ...
# 5995  Lillestrøm                   2
# 5996  Lillestrøm                   2
# 5997      Sagene                   3
# 5998  Gamle Oslo                   5
# 5999  Lillestrøm                  -5
#
# [6000 rows x 2 columns]

# %%
groupkommune = passasjerer_kommuner

# %%
groupkommune
# Out:
#          Kommune  Passasjerer_Ombord
# 0          Bærum                   5
# 1          Bærum                   5
# 2          Bærum                   6
# 3          Bærum                  10
# 4          Bærum                  10
# ...          ...                 ...
# 5995  Lillestrøm                   2
# 5996  Lillestrøm                   2
# 5997      Sagene                   3
# 5998  Gamle Oslo                   5
# 5999  Lillestrøm                  -5
#
# [6000 rows x 2 columns]

# %%
groupkommune.groupby('Kommune').sum()
# Out:
#                    Passasjerer_Ombord
# Kommune
# Alna                             2198
# Asker                            1730
# Aurskog-Høland                    570
# Bjerke                           1494
# Bærum                            1601
# Drammen                            42
# Eidsvoll                          583
# Enebakk                           338
# Frogner                           209
# Gamle Oslo                       1781
# Gjerdrum                          358
# Grorud                            491
# Grünerløkka                       651
# Hurdal                             24
# Indre Østfold                      19
# Lier                              178
# Lillestrøm                       5022
# Lørenskog                        2397
# Nannestad                         507
# Nes                               312
# Nittedal                          932
# Nordmarka                         -17
# Nordre Aker                        26
# Nordre Follo                       33
# Nordstrand                        302
# Rælingen                         1049
# Sagene                            222
# Sentrum                           423
# St.Hanshaugen                     156
# Stovner                           770
# Søndre Nordstrand                 113
# Ullensaker                       1577
# Ullern                            490
# Vestre Aker                       496

# %%
passPrKommune = main_df.groupby(['Kommune'])['Passasjerer_Ombord'].sum().sort_values(ascending=True)

# %%
plt.xlabel('Sum Passasjerer')
passPrKommune.plot(figsize=(20,20),kind='barh')
# Out:
# <AxesSubplot:xlabel='Sum Passasjerer', ylabel='Kommune'>
